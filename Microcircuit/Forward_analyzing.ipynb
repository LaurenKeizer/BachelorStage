# %%
import os, sys, inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

from brian2 import *
import Documentation.parameters as p

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

import Backward as forw

defaultclock = p.dt*ms
# Out:
# INFO       Cache size for target "cython": 1456 MB.
# You can call "clear_cache('cython')" to delete all files from the cache or manually delete files in the "C:\Users\laure\.cython\brian_extensions" directory. [brian2]

# %%
scales  = [17,18,19,21, 23]
weights = [3,5,7,9,11,13,15]

# %%
data_PC = pd.DataFrame()
data_IN = pd.DataFrame()

for scale in scales:
    output_PC, output_IN, spiketrain = forw.forward_run(scale, weights, p.seed)
    output_PC.replace(r'\\n', ' ', regex= True)
    output_IN.replace(r'\\n', ' ', regex= True)

    data_IN = pd.concat([data_IN, output_IN])
    data_PC = pd.concat([data_PC, output_PC])
# Out:
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# [[0. 0. 0. ... 0. 0. 0.]]
# no down spikes, inventing one
# ...

# %%
# Out:
#   weights scales      Hxx       Hxy      MI_i  \
# 0       3     17  0.86421  0.606272  0.257938
# 0       5     17  0.86421  0.606272  0.257938
# 0       7     17  0.86421  0.606272  0.257938
# 0       9     17  0.86421  0.606272  0.257938
# 0      11     17  0.86421  0.606272  0.257938
# 0      13     17  0.86421  0.606272  0.257938
# 0      15     17  0.86421  0.606272  0.257938
# 0       3     18  0.86421  0.606272  0.257938
# 0       5     18  0.86421  0.606272  0.257938
# 0       7     18  0.86421  0.606272  0.257938
# 0       9     18  0.86421  0.606272  0.257938
# 0      11     18  0.86421  0.606272  0.257938
# 0      13     18  0.86421  0.606272  0.257938
# 0      15     18  0.86421  0.606272  0.257938
# 0       3     19  0.86421  0.606272  0.257938
# 0       5     19  0.86421  0.606272  0.257938
# 0       7     19  0.86421  0.606272  0.257938
# 0       9     19  0.86421  0.606272  0.257938
# 0      11     19  0.86421  0.606272  0.257938
# ...

# %%
a = result['MI'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 a = result['MI'].to_numpy()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
b = result['scales'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 b = result['scales'].to_numpy()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
c = result['weights'].to_numpy()

# %%
# Out:
# array([[3, 17, 0.8642096949629969, 0.6062719060810288,
#         0.25793778888196817,
#         array([0.33333333, 0.33333333, 0.33333333, ..., 0.74388497, 0.74403603,
#                0.744168  ])                                                    ,
#         0.13567745408636117, 0.8642096949629969, 3.0267177419250557,
#         -2.162508046962059, 0.0010469742444335869, 0.0001401620273035629,
#         array([0.33333333, 0.25061795, 0.18285261, ..., 0.00066219, 0.00066219,
#                0.00066219])                                                    ,
#         0.28616575413888456, 0.2984666688945353, -8.38383571610602],
#        [5, 17, 0.8642096949629969, 0.6062719060810288,
#         0.25793778888196817,
#         array([0.33333333, 0.33333333, 0.33333333, ..., 0.74388497, 0.74403603,
#                0.744168  ])                                                    ,
#         0.13567745408636117, 0.8642096949629969, 3.0267177419250557,
# ...

# %%
result = data_PC[['scales', 'weights','MI']].to_numpy()

# %%
# Out:
# numpy.ndarray

# %%
sns.heatmap(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 sns.heatmap(result)
#
# File C:\ProgramData\Anaconda3\envs\stage\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File C:\ProgramData\Anaconda3\envs\stage\lib\site-packages\seaborn\matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...

# %%
ig, ax = plt.subplots(figsize=(13,7))

# Add title to the Heat map
title = "MI Heatmap"

# Set the font size and the distance of the title from the plot
plt.title(title,fontsize=18)
ttl = ax.title
ttl.set_position([0.5,1.05])

# Hide ticks for X & Y axis
ax.set_xticks([])
ax.set_yticks([])

# Remove the axes
ax.axis('off')
sns.heatmap(result,annot=labels,fmt="",cmap='RdYlGn',linewidths=0.30,ax=ax)

# Display the Pharma Sector Heatmap
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 17>()
#      15 # Remove the axes
#      16 ax.axis('off')
# ---> 17 sns.heatmap(result,annot=labels,fmt="",cmap='RdYlGn',linewidths=0.30,ax=ax)
#      19 # Display the Pharma Sector Heatmap
#      20 plt.show()
#
# File C:\ProgramData\Anaconda3\envs\stage\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
